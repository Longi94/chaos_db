# %%
import pandas as pd

# %%
heap_results = pd.read_csv('results_1000_heap.csv')
heap_results
# Out:
#      iteration  result  exited  return_code  signaled  term_sig    runtime  \
# 0            0       0    True            0     False         0  17.320666
# 1            1       0    True            0     False         0  17.264898
# 2            2       0    True            0     False         0  17.288970
# 3            3       0    True            0     False         0  17.334837
# 4            4       0    True            0     False         0  17.283378
# ..         ...     ...     ...          ...       ...       ...        ...
# 995        995       0    True            0     False         0  17.185825
# 996        996       0    True            0     False         0  16.801182
# 997        997       0    True            0     False         0  16.848816
# 998        998       0    True            0     False         0  16.942678
# 999        999       0    True            0     False         0  16.809496
#
#      inject_delay
# 0            5363
# 1            7442
# ...

# %%
heap_results.groupby(['result', 'exited', 'return_code', 'signaled', 'term_sig']).size().reset_index(name='count')
# Out:
#    result  exited  return_code  signaled  term_sig  count
# 0       0    True            0     False         0    982
# 1       2   False            0      True         6      2
# 2       2   False            0      True        11     16

# %%
heap_results[heap_results['term_sig'] == 6]
# Out:
#      iteration  result  exited  return_code  signaled  term_sig    runtime  \
# 317        317       2   False            0      True         6  18.300679
# 506        506       2   False            0      True         6  17.738479
#
#      inject_delay
# 317          9986
# 506          7933

# %%
heap_results[heap_results['term_sig'] == 11]
# Out:
#      iteration  result  exited  return_code  signaled  term_sig    runtime  \
# 8            8       2   False            0      True        11  17.703714
# 107        107       2   False            0      True        11   0.921512
# 116        116       2   False            0      True        11   2.687289
# 129        129       2   False            0      True        11   5.121287
# 141        141       2   False            0      True        11   7.129130
# 226        226       2   False            0      True        11   1.149205
# 318        318       2   False            0      True        11   6.834395
# 333        333       2   False            0      True        11   3.093286
# 340        340       2   False            0      True        11  17.841481
# 418        418       2   False            0      True        11  17.417867
# 491        491       2   False            0      True        11  17.705797
# ...

# %%
stack_results = pd.read_csv('results_1000_stack.csv')
stack_results
# Out:
#      iteration  result  exited  return_code  signaled  term_sig    runtime  \
# 0            0       0    True            0     False         0  17.283306
# 1            1       0    True            0     False         0  17.408450
# 2            2       0    True            0     False         0  17.292255
# 3            3       0    True            0     False         0  17.349961
# 4            4       0    True            0     False         0  17.322786
# ..         ...     ...     ...          ...       ...       ...        ...
# 995        995       0    True            0     False         0  17.032969
# 996        996       0    True            0     False         0  17.265038
# 997        997       0    True            0     False         0  16.904729
# 998        998       0    True            0     False         0  17.072478
# 999        999       0    True            0     False         0  16.715849
#
#      inject_delay
# 0            9815
# 1           10892
# ...

# %%
stack_results.groupby(['result', 'exited', 'return_code', 'signaled', 'term_sig']).size().reset_index(name='count')
# Out:
#    result  exited  return_code  signaled  term_sig  count
# 0       0    True            0     False         0    997
# 1       2   False            0      True        11      3
